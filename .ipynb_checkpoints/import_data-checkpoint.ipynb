# %%
#importing all data in at once
import nltk
import pandas as pd
import csv
import re
import numpy as np
import os
import gensim
import pattern
import glob
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk import ngrams
from gensim import corpora, models

# %%
#Generate file names using glob
_2018filenames = [I for I in glob.glob('data/2018/*.txt')]
_2019filenames = [I for I in glob.glob('data/2019/*.txt')]
_2020filenames = [I for I in glob.glob('data/2020/*.txt')]
_2021filenames = [I for I in glob.glob('data/2021/*.txt')]
_2022filenames = [I for I in glob.glob('data/2022/*.txt')]

#TO REMOVE: TEST CASE FOR BIGRAMS
test_data = open(r"./data/TEST1.txt", "r").read()
list_test = list()
list_test.append(test_data)

#Save the 
list_2018 = list()

list_2019 = list()

list_2020 = list()

list_2021 = list()

list_2022 = list()

for file in _2018filenames:
    case = open(r"" + file + "", "r")
    list_2018.append(case)

for file in _2019filenames:
    case = open(r"" + file + "", "r")
    list_2019.append(case)

for file in _2020filenames:
    case = open(r"" + file + "", "r")
    list_2020.append(case)

for file in _2021filenames:
    case = open(r"" + file + "", "r")
    list_2021.append(case)

for file in _2022filenames:
    case = open(r"" + file + "", "r")
    list_2022.append(case)

#Print lengths
print("There are " + str(len(list_2018)) + " CEQA cases to analyze in 2018.")
print("There are " + str(len(list_2019)) + " CEQA cases to analyze in 2019.")
print("There are " + str(len(list_2020)) + " CEQA cases to analyze in 2020.")
print("There are " + str(len(list_2021)) + " CEQA cases to analyze in 2021.")
print("There are " + str(len(list_2022)) + " CEQA cases to analyze in 2022.")
# Out:
# There are 217 CEQA cases to analyze in 2018.
# There are 235 CEQA cases to analyze in 2019.
# There are 192 CEQA cases to analyze in 2020.
# There are 211 CEQA cases to analyze in 2021.
# There are 116 CEQA cases to analyze in 2022.

# %%
#Import default NLTK stopwords
from nltk.corpus import stopwords
#Add more stopwords
adtl_stopwords = pd.read_csv("./preprocessing/test_stopwords.csv", header = None)
adtl_stopwords = adtl_stopwords.values.tolist()
adtl_stopwords = adtl_stopwords[0]

#Combine with default stopwords list
stopwords_def = stopwords.words('english')
stopwords_def.extend(adtl_stopwords)
print(stopwords_def)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'could', 'would', 'esq', 'also', 'may', 'plaintiff', 'petitioner', 'defendant', 'respondent', 'action', nan]

# %%
from pattern.en import singularize
from nltk.corpus import words
from nltk.corpus import wordnet
from nltk import pos_tag

#for i in range(len(list_2018)):
for i in range(len(list_test)):

    #Step 1: RegEx processing
    
    #Read in the data as 'read'
    draft_case = list_2018[i].read()
   
    ##Use regex to do a preliminary cleaning of the content
    ### Remove punctuation and numbers
    draft_case = re.sub("[0-9]", "", draft_case) #Removes numbers
    draft_case = re.sub(r"\/", " ", draft_case) #Replaces slashes with spaces
    draft_case = re.sub(r"\'", " ", draft_case) #Replaces apostrophes with spaces
    draft_case = re.sub(r"\-", " ", draft_case) #Replaces en-dash with spaces
    draft_case = re.sub(r"\–", " ", draft_case) #Replaces em-dash with spaces
    draft_case = re.sub(r"[.,?!()•$;:@§%&~\[\]\"]", "", draft_case) #Removes extraneous punctuation
    draft_case = re.sub(r"^$n','\n", "", draft_case, re.MULTILINE) #Removes empty lines
    draft_case = re.sub(r"\b\w{1,2}\b", '', draft_case) #Removes all one and two-character words (none have meaning)
    draft_case = re.sub(r"\n","", draft_case) #Removes extraneous line breaks
    
    #Remove extraneous information about lawyers and case detail that doesn't impact the content of the case
    starting_phrase = "PRELIMINARY STATEMENT" #Use this as the starter for when the actual lawsuit begins
    remove_before = r'^.*?{}'.format(re.escape(starting_phrase))
    draft_case = re.sub(remove_before, "", draft_case, flags=re.DOTALL)
    
    #Remove "FIRST AMENDED COMPLAINT", which is at the bottom of every page
    draft_case = re.sub(r"FIRST AMENDED COMPLAINT", "", draft_case)
    
    #These steps are done last since other words' removal will impact them
    draft_case = re.sub(r"\s+", " ", draft_case) #Removes multiple whitespaces
    draft_case = re.sub(r"([a-z])([A-Z])", r"\1 \2", draft_case) #Separates words that were joined together by double spaces

    #Step 2: Tokenization and singularization
    
    #Word tokenization
    draft_case = word_tokenize(draft_case)
    
    #Depluralize all nouns
    #Find words that end with 's' that need to be handled differently than plurals
    exceptions = pd.read_csv('./preprocessing/singularized_exceptions.csv')
    exceptions_list = exceptions.to_dict('records')
    exceptions_list = exceptions_list[0]
    
    #Set a function to process these words differently
    def singularize_esp(word):
        if word in exceptions_list:
            return exceptions_list.get(word)
        return singularize(word)
    
    draft_case = [singularize_esp(word) for word in draft_case]

    #Step 3: Remove all non-real words

    #Define words as anything distinct in these two NLTK sets
    real_word_set = set(words.words() + list(wordnet.words()))
    
    #Want to keep certain words capitalized
    proper_nouns = pd.read_csv('./preprocessing/proper_nouns.csv', header = None)
    proper_nouns = proper_nouns.values.tolist()
    proper_nouns = proper_nouns[0]
    
    def recapitalize(word):
        if word in proper_nouns:
            return word
        if word.lower() in real_word_set:
            return word.lower()   
        else:
            return word
            
    draft_case = [recapitalize(word) for word in draft_case]
    
    draft_case = [word for word in draft_case if (word in real_word_set or word in proper_nouns)]

    #Step 4: implement n-grams
    draft_case = ' '.join(draft_case)
    print(draft_case)
    ##Create n-grams using pointwise mutual information

    ###Create bigrams and use PMI to score them
    bigram_measures = nltk.collocations.BigramAssocMeasures()
    bigram_finder = nltk.collocations.BigramCollocationFinder.from_words(str.split(draft_case))
    ####Apply a frequency filter
    bigram_finder.apply_freq_filter(5)
    bigram_scores = bigram_finder.score_ngrams(bigram_measures.pmi)
    print(bigram_scores)
    
    ###Do the same for trigrams
    trigram_measures = nltk.collocations.TrigramAssocMeasures()
    trigram_finder = nltk.collocations.TrigramCollocationFinder.from_words(str.split(draft_case))
    ####Frequency filter
    trigram_finder.apply_freq_filter(5)
    trigram_scores = trigram_finder.score_ngrams(trigram_measures.pmi)
    print(trigram_scores)
    
    #Store the scores as dataframes
    
    bigram_pmi = pd.DataFrame(bigram_scores)
    print(bigram_pmi.head())
    bigram_pmi.columns = ['bigram', 'pmi']
    bigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)
    #Save only the bigrams with PMI greater than 5 (arbitrary threshold)
    bigram_pmi = bigram_pmi[bigram_pmi.apply(lambda bigram: bigram.pmi > 4, axis = 1)][:500]
    
    trigram_pmi = pd.DataFrame(trigram_scores)
    print(trigram_pmi.head())
    trigram_pmi.columns = ['trigram', 'pmi']
    trigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)
    #Save only the trigrams with PMI greater than 5 (arbitrary threshold)
    trigram_pmi = trigram_pmi[trigram_pmi.apply(lambda trigram: trigram.pmi > 4, axis = 1)][:500]
    
    #Keep only the values
    bigrams = [' '.join(x) for x in bigram_pmi.bigram.values]
    trigrams = [' '.join(x) for x in trigram_pmi.trigram.values]
    
    # Concatenate n-grams
    def replace_ngram(x):
        for gram in bigrams:
            x = x.replace(gram, '_'.join(gram.split()))
        for gram in trigrams:
            x = x.replace(gram, '_'.join(gram.split()))
        return x
    
    draft_case = replace_ngram(draft_case)

    #Step 5: Lemmatize output

    #Lemmatization
    lemmatizer = WordNetLemmatizer()
    
    #Tag by part of speech
    
    tagged_word_content = pos_tag(draft_case)
    
    
    #Need to lemmatize using part of speech to ensure accuracy
    def pos_lemmatize(word, tag):
        if tag.startswith('J'):
            return lemmatizer.lemmatize(word, pos='a')  # Adjective
        elif tag.startswith('V'):
            return lemmatizer.lemmatize(word, pos='v')  # Verb
        elif tag.startswith('N'):
            return lemmatizer.lemmatize(word, pos='n')  # Noun
        elif tag.startswith('R'):
            return lemmatizer.lemmatize(word, pos='r')  # Adverb
        else:
            return lemmatizer.lemmatize(word)  # Default to noun
    
    # Lemmatize using part of speech
    lemmatized_output = [pos_lemmatize(word, tag) for word, tag in tagged_word_content]

    list_2018[i] = lemmatized_output
# Out:
# law office abigail smith abigail smith road suite San Diego telephone facsimile email attorney for petitioner sierra club superior court the state californium county riverside sierra club case petitioner judge valley action may respondent notice attorney and do through CEQA petition for writ inclusive mandate real party interest pub re case designation CEQA the attorney general the state californium please take notice pursuant public resource code section that may petitioner sierra club verified petition for peremptory writ mandate pursuant the California environmental quality act CEQA challenging the approval the city Moreno valley the Moreno valley logistic notice attorney project the project the project will develop industrial warehouse complex square foot vacant acre immediately adjacent existing residence the city Moreno valley for the reason alleged the verified petition for peremptory writ mandate transmitted herewith the decision the project environmental impact report must overturned dated may respectfully law office abigail smith abigail smith attorney for petitioner notice attorney service and certification employed the county San Diego state California over the age and not party the within action business road suite San Diego may the foregoing document described notice attorney general CEQA petition for writ mandate causing true copy thereof the party and set forth below office the attorney general street Sacramento mail priority mail such envelope for priority mail service with the postal service aware that motion the party service invalid the postage cancellation date postage meter date the envelope more than one day after the date deposit for mailing set forth this declaration declare under penalty perjury under the law the state California that the foregoing true and correct executed may San Diego abigail smith proof californium law office abigail smith may smith road suite San Diego telephone ey facsimile email attorney for petitioner sierra club superior court the state californium county club petitioner case judge department city valley action respondent verified petition for writ and do through mandate inclusive real party interest code and cal pub re state CEQA guideline case designation CEQA verified petition for writ mandate introduction action challenge the approval respondent city Moreno valley city about april the Moreno valley logistic center project certification final environmental impact report specific plan amendment and all related land use approval collectively the the project the Moreno valley logistic center project concern the construction building square foot industrial space acre vacant land the city Moreno valley the project will operate high cube warehouse logistic center meaning that diesel truck primarily traveling from the port long beach and lo will bring cargo the warehouse building for storage and sorting for transport other truck destination and outside California these operation will occur hour per day seven day per week the project site adjacent existing single yet the adverse and significant impact associated with the project have not been adequately and mitigated violation the California environmental quality CEQA public resource code the city Moreno valley certification the final environmental impact report for the project must because the record lack substantial evidence support the conclusion and because the fail adequately describe disclose relevant information also the project result significant and unavoidable impact but mitigation ineffective reduce impact additionally the city improperly rejected feasible mitigation measure and project alternative that would lessen some the project harmful environmental effect verified petition for writ mandate during the administrative review process the city was notified that there was need for further and mitigation due the project adverse environmental effect spite these reasoned comment the record the city approved the project and ...
# [(('road', 'suite'), 9.305605789585428), (('logistic', 'center'), 8.820178962415188), (('set', 'forth'), 8.820178962415188), (('calendar', 'item'), 8.62753388447279), (('San', 'Diego'), 8.457608883030478), (('suite', 'San'), 8.457608883030478), (('general', 'calendar'), 8.168102265835493), (('specific', 'plan'), 8.168102265835493), (('substantial', 'evidence'), 8.135680788143116), (('lead', 'agency'), 8.042571383751635), (('do', 'through'), 7.9721820558602365), (('real', 'party'), 7.927094166331699), (('solar', 'energy'), 7.927094166331699), (('square', 'foot'), 7.820178962415187), (('air', 'quality'), 7.637587549136715), (('abigail', 'smith'), 7.6275338844727925), (('sierra', 'club'), 7.5400710432224525), (('law', 'office'), 7.527998210921877), (('office', 'abigail'), 7.527998210921877), (('plan', 'amendment'), 7.490030360722856), (('indian', 'street'), 7.414540161138595), (('party', 'interest'), 7.190128572165493), (('public', 'resource'), 7.168102265835495), (('resource', 'code'), 7.103971928415779), (('land', 'use'), 7.064597690081635), (('verified', 'petition'), 7.0425713837516355), (('Moreno', 'valley'), 6.872646382309323), (('writ', 'mandate'), 6.749212441061044), (('mitigation', 'measure'), 6.720643288864273), (('impact', 'report'), 6.498250867527825), (('CEQA', 'guideline'), 6.498250867527824), (('feasible', 'mitigation'), 6.4576088830304785), (('valley', 'logistic'), 6.3872195551390805), (('smith', 'abigail'), 6.042571383751635), (('state', 'California'), 5.840937522581985), (('significant', 'environmental'), 5.682675438665251), (('petitioner', 'sierra'), 5.5571445565813935), (('this', 'action'), 5.512056667052855), (('environmental', 'impact'), 5.498250867527826), (('petition', 'for'), 5.390494687171943), (('foot', 'with'), 5.334752135244946), (('city', 'Moreno'), 5.28357948325543), (('for', 'writ'), 5.187211088783199), (('state', 'CEQA'), 5.144613912913124), (('respondent', 'city'), 4.905067860001699), (('other', 'that'), 4.812150588659254), (('project', 'site'), 4.301104397350489), (('attorney', 'for'), 4.261211670226976), (('and', 'other'), 4.2446151596962824), (('project', 'will'), 3.7705896806517085), (('project', 'alternative'), 3.507555274817914), (('the', 'project'), 2.881927167710721), (('petitioner', 'and'), 2.8022570544179253), (('for', 'petitioner'), 2.7757848430567336), (('the', 'city'), 2.7654131589842965), (('the', 'record'), 2.6658774854333807), (('within', 'the'), 2.5954881575419826), (('item', 'the'), 2.5023787531505004), (('the', 'lead'), 2.5023787531505004), (('the', 'council'), 2.373095736205535), (('approval', 'the'), 2.350375659705451), (('the', 'requirement'), 2.3324537517081882), (('with', 'the'), 1.8325273548428331), (('that', 'the'), 1.7004577171435251), (('the', 'state'), 1.6568887022061265), (('street', 'the'), 1.4149159119001613), (('the', 'Moreno'), 1.3059815403469983), (('for', 'the'), 0.9434114609622899), (('impact', 'the'), 0.37309573620553493), (('project', 'the'), -0.10158470950070964), (('and', 'the'), -0.4045118424580174)]
# [(('road', 'suite', 'San'), 17.76321467261591), (('suite', 'San', 'Diego'), 17.277787845445665), (('general', 'calendar', 'item'), 16.795636150308283), (('specific', 'plan', 'amendment'), 16.795636150308283), (('real', 'party', 'interest'), 16.23269995591713), (('law', 'office', 'abigail'), 15.248641499786151), (('office', 'abigail', 'smith'), 15.15553209539467), (('public', 'resource', 'code'), 14.272074194251273), (('abigail', 'smith', 'abigail'), 13.763214672615907), (('smith', 'abigail', 'smith'), 13.670105268224427), (('environmental', 'impact', 'report'), 13.666353133363321), (('state', 'CEQA', 'guideline'), 13.602222795943604), (('Moreno', 'valley', 'logistic'), 13.555321820974575), (('petitioner', 'sierra', 'club'), 13.097215599803846), (('verified', 'petition', 'for'), 12.543248988674), (('petition', 'for', 'writ'), 12.229782472534835), (('city', 'Moreno', 'valley'), 12.156225865564755), (('for', 'writ', 'mandate'), 11.704320983562338), (('the', 'lead', 'agency'), 10.544950136902136), (('attorney', 'for', 'petitioner'), 10.496428131921009), (('petitioner', 'and', 'other'), 10.190325004195326), (('and', 'other', 'that'), 9.684796970968577), (('the', 'Moreno', 'valley'), 8.178627922656322), (('the', 'city', 'Moreno'), 7.933515424819788), (('the', 'project', 'site'), 7.481555055613629), (('the', 'project', 'will'), 6.951040338914851), (('that', 'the', 'project'), 5.508522103213895), (('for', 'the', 'project'), 4.344051531863691), (('the', 'project', 'the'), 2.789359331567443)]
#                     0         1
# 0       (road, suite)  9.305606
# 1  (logistic, center)  8.820179
# 2        (set, forth)  8.820179
# 3    (calendar, item)  8.627534
# 4        (San, Diego)  8.457609
#                              0          1
# 0           (road, suite, San)  17.763215
# 1          (suite, San, Diego)  17.277788
# 2    (general, calendar, item)  16.795636
# 3  (specific, plan, amendment)  16.795636
# 4      (real, party, interest)  16.232700
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[139], line 137
#     135 #Tag by part of speech
#     136 from nltk import pos_tag
# --> 137 tagged_word_content = pos_tag(draft_case)
#     140 #Need to lemmatize using part of speech to ensure accuracy
#     141 def pos_lemmatize(word, tag):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nltk/tag/__init__.py:166, in pos_tag(tokens, tagset, lang)
#     141 """
#     142 Use NLTK's currently recommended part of speech tagger to
#     143 tag the given list of tokens.
#    (...)
#     163 :rtype: list(tuple(str, str))
#     164 """
#     165 tagger = _get_tagger(lang)
# --> 166 return _pos_tag(tokens, tagset, tagger, lang)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nltk/tag/__init__.py:120, in _pos_tag(tokens, tagset, tagger, lang)
#     118 # Throws Error if tokens is of string type
#     119 elif isinstance(tokens, str):
# --> 120     raise TypeError("tokens: expected a list of strings, got a string")
#     122 else:
#     123     tagged_tokens = tagger.tag(tokens)
#
# TypeError: tokens: expected a list of strings, got a string

# %%
#now, implement n-grams

#Step 4: implement n-grams
##Create n-grams using pointwise mutual information

###Create bigrams and use PMI to score them
bigram_measures = nltk.collocations.BigramAssocMeasures()
bigram_finder = nltk.collocations.BigramCollocationFinder.from_words(str.split(draft_case))
####Apply a frequency filter
bigram_finder.apply_freq_filter(25)
bigram_scores = bigram_finder.score_ngrams(bigram_measures.pmi)

###Do the same for trigrams
trigram_measures = nltk.collocations.TrigramAssocMeasures()
trigram_finder = nltk.collocations.TrigramCollocationFinder.from_words(str.split(draft_case))
####Frequency filter
trigram_finder.apply_freq_filter(25)
trigram_scores = trigram_finder.score_ngrams(trigram_measures.pmi)

#Store the scores as dataframes

bigram_pmi = pd.DataFrame(bigram_scores)
print(bigram_pmi.head())
bigram_pmi.columns = ['bigram', 'pmi']
bigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)
#Save only the bigrams with PMI greater than 5 (arbitrary threshold)
bigram_pmi = bigram_pmi[bigram_pmi.apply(lambda bigram: bigram.pmi > 4, axis = 1)][:500]

trigram_pmi = pd.DataFrame(trigram_scores)
print(trigram_pmi.head())
trigram_pmi.columns = ['trigram', 'pmi']
trigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)
#Save only the trigrams with PMI greater than 5 (arbitrary threshold)
trigram_pmi = trigram_pmi[trigram_pmi.apply(lambda trigram: trigram.pmi > 4, axis = 1)][:500]

#Keep only the values
bigrams = [' '.join(x) for x in bigram_pmi.bigram.values]
trigrams = [' '.join(x) for x in trigram_pmi.trigram.values]

# Concatenate n-grams
def replace_ngram(x):
    for gram in bigrams:
        x = x.replace(gram, '_'.join(gram.split()))
    for gram in trigrams:
        x = x.replace(gram, '_'.join(gram.split()))
    return x

draft_case_ngrammed = replace_ngram(draft_case)
# Out:
# ['steven', 'esq', 'patrick', 'esq', 'the', 'law', 'office', 'young', 'street', 'fourth', 'floor', 'Bakersfield', 'telephone', 'facsimile', 'email', 'attorney', 'for', 'petitioner', 'water', 'district', 'exempt', 'from', 'file', 'fee', 'code', 'superior', 'court', 'the', 'state', 'californium', 'for', 'the', 'county', 'tulare', 'water', 'district', 'California', 'case', 'water', 'district', 'notice', 'attorney', 'general', 'petitioner', 'south', 'valley', 'water', 'banking', 'authority', 'California', 'joint', 'power', 'authority', 'do', 'inclusive', 'respondent', 'irrigation', 'district', 'California', 'irrigation', 'district', 'irrigation', 'district', 'California', 'irrigation', 'district', 'do', 'party', 'interest', 'notice', 'attorney', 'general', 'the', 'attorney', 'general', 'the', 'state', 'California', 'please', 'take', 'notice', 'under', 'public', 'resource', 'code', 'and', 'code', 'civil', 'procedure', 'that', 'january', 'petitioner', 'water', 'district', 'petition', 'for', 'writ', 'mandate', 'against', 'south', 'valley', 'water', 'bank', 'the', 'tulare', 'county', 'superior', 'court', 'the', 'petition', 'allege', 'among', 'other', 'thing', 'that', 'the', 'authority', 'properly', 'follow', 'and', 'requirement', 'CEQA', 'several', 'way', 'but', 'not', 'limited', 'failure', 'prepare', 'environmental', 'impact', 'report', 'for', 'the', 'project', 'despite', 'the', 'existence', 'substantial', 'evidence', 'fair', 'argument', 'one', 'more', 'potentially', 'significant', 'environmental', 'impact', 'but', 'limited', 'impact', 'from', 'land', 'subsidence', 'surface', 'and', 'quality', 'impact', 'and', 'interference', 'with', 'surround', 'well', 'improper', 'preparation', 'negative', 'declaration', 'failure', 'analyze', 'impact', 'outside', 'the', 'project', 'area', 'and', 'failure', 'adequately', 'analyze', 'cumulative', 'impact', 'generally', 'speak', 'the', 'petition', 'seek', 'the', 'following', 'among', 'other', 'relief', 'writ', 'mandate', 'void', 'and', 'set', 'aside', 'all', 'project', 'approval', 'the', 'mitigated', 'negative', 'declaration', 'finding', 'and', 'mitigation', 'monitoring', 'and', 'report', 'program', 'and', 'direct', 'the', 'authority', 'prepare', 'before', 'any', 'future', 'consideration', 'approval', 'the', 'project', 'implementation', 'the', 'same', 'declaratory', 'relief', 'preliminary', 'and', 'permanent', 'injunction', 'and', 'cost', 'suit', 'and', 'attorney', 'fee', 'copy', 'the', 'petition', 'attach', 'this', 'notice', 'date', 'january', 'the', 'law', 'office', 'young', 'jeff', 'for', 'petitioner', 'water', 'attorney', 'esq', 'patrick', 'esq', 'the', 'law', 'office', 'young', 'street', 'fourth', 'floor', 'Bakersfield', 'telephone', 'tulare', 'county', 'superior', 'court', 'facsimile', 'email', 'jan', 'stephane', 'for', 'petitioner', 'water', 'district', 'exempt', 'from', 'file', 'code', 'superior', 'court', 'the', 'state', 'californium', 'for', 'the', 'county', 'tulare', 'water', 'district', 'California', 'case', 'water', 'district', 'petitioner', 'petition', 'for', 'writ', 'mandate', 'and', 'complaint', 'for', 'declaratory', 'relief', 'south', 'valley', 'water', 'bank', 'CEQA', 'public', 'resource', 'code', 'authority', 'California', 'joint', 'power', 'authority', 'do', 'inclusive', 'irrigation', 'district', 'California', 'irrigation', 'district', 'irrigation', 'district', 'district', 'do', 'inclusive', 'real', 'party', 'interest', 'petition', 'for', 'writ', 'mandate', 'and', 'complaint', 'for', 'declaratory', 'and', 'plaintiff', 'water', 'district', 'hereafter', 'petitioner', 'bring', 'this', 'petition', 'for', 'writ', 'mandate', 'and', 'complaint', 'for', 'declaratory', 'relief', 'petition', 'and', 'allege', 'follow', 'introduction', 'project', 'and', 'party', 'petition', 'challenge', 'pursuant', 'the', 'California', 'environmental', 'quality', 'act', 'CEQA', 'and', 'it', 'regulation', 'California', 'code', 'regulation', 'title', 'chapter', 'CEQA', 'guideline', 'certain', 'action', 'and', 'de ...
